# %%
import pandas as pd
# Set options to display all columns and increase max column width to show full text
pd.set_option('display.max_columns', None)       # Display all columns
pd.set_option('display.max_colwidth', None)      # Display full text in each column
df = pd.read_csv("../Data/output/research_papers.csv")
display(df)
# Out:
#                                                                                                                                                                              filename  \
# 0   2019., Chaobo Zhang, An improved association rule mining-based method for revealing operational problems of building heating, ventilation and air conditioning (HVAC) systems.pdf
# 1                                                 A_Reversible_Residual_Network-Aided_Canonical_Correlation_Analysis_to_Fault_Detection_and_Diagnosis_in_Electrical_Drive_Systems.pdf
# 2          Autonomous fault detection and diagnosis for permanent magnet synchronous motors using combined variational mode decomposition, the hilbert-huang transform, and a CNN.pdf
# 3                                                                                                                      Digital twin enabled FDD process for building HVAC systems.pdf
# ...
