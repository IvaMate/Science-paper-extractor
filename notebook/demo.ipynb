# %%
import sys
from pathlib import Path
import src.main as main_module
from pathlib import Path

# Add project root to sys.path
project_root = Path("..").resolve()
sys.path.append(str(project_root))

# Use temp/demo paths so no new folders are created
demo_pdf_folder = Path("../data/input")   # or wherever you have demo PDFs
demo_output_csv = Path("../data/output/research_papers.csv")

# Call main() with custom paths
main_module.main(
    pdf_folder=demo_pdf_folder,
    output_csv=demo_output_csv
)

# %%
import pandas as pd

df= pd.read_csv("/home/ivam/project/Science-paper-extractor/Data/output/research_papers_data.csv")

display(df)
# Out:
#                                              filename  \
# 0   2019., Chaobo Zhang, An improved association r...
# 1   Fault detection and diagnosis for Air Handling...
# 2   Novel Actuator Fault Diagnosis Framework for M...
# 3   2021., Zhang, Fault detection and diagnosis fo...
# 4   2021., Chaobo Zhang, Analytic hierarchy proces...
# 5   Fault Detection and Diagnosis in AHU System wi...
# 6   2019.,Chakraborty, Early detection of faults i...
# 7   Hybrid Random Forest and Support Vector Machin...
# 8   An explainable one-dimensional convolutional n...
# 9   An Online Data-Driven Fault Diagnosis Method f...
# 10  Model-based Fault Detection and Diagnosis for ...
#
#                                                 title  \
# 0   An improved association rule mining-based meth...
# 1   Fault detection and diagnosis for Air Handling...
# 2   Novel Actuator Fault Diagnosis Framework for M...
# 3   Fault detection and diagnosis for the screw ch...
# ...
